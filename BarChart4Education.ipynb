# %%
import pandas as pd
import matplotlib as plt
data = pd.read_csv('EDUC4count.csv')

# %%
Country1 = data[["Country","Time","Value"]][(data.LOCATION == 'COL') & (data.Time > 2003) & (data.Time < 2013)].Value
Country2 = data[["Country","Time","Value"]][(data.LOCATION == 'MEX') & (data.Time > 2003) & (data.Time < 2013)].Value
Country3 = data[["Country","Time","Value"]][(data.LOCATION == 'IND') & (data.Time > 2003) & (data.Time < 2013)].Value
Country4 = data[["Country","Time","Value"]][(data.LOCATION == 'USA') & (data.Time > 2003) & (data.Time < 2013)].Value

Country1 = Country1.tolist()
Country2 = Country2.tolist()
Country3 = Country3.tolist()
Country4 = Country4.tolist()

vc = [Country1,Country2,Country3,Country4]

# %%
print(vc)
# Out:
# [[26.61448, 29.185129999999997, 31.331640000000004, 32.63217, 35.24565, 37.07863, 39.4091, 43.502959999999995, 46.21575], [22.56222, 23.12034, 23.60797, 24.142979999999998, 24.7486, 25.19286, 26.166439999999998, 27.03765, 28.307440000000003], [10.98428, 10.73016, 11.540560000000001, 13.188770000000002, 15.1171, 16.10299, 17.91149, 22.86137, 24.36533], [81.46356, 82.08444, 82.053, 83.03106, 85.00681999999999, 88.58174, 94.22801, 96.3224, 94.84228]]

# %%
namelist = data[["Time","Value"]][(data.LOCATION == 'COL') & (data.Time > 2003) & (data.Time < 2013)].Time
namelist = namelist.tolist()

# %%
namelist
# Out:
# [2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012]

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# data to plot
n_groups = 9 #yıl sayısı
fsize = 14
# create plot
fig, ax = plt.subplots(figsize=(15, 7))
index = np.arange(n_groups)
bar_width = 0.35 / 2
opacity = 0.8
 
rects1 = plt.bar(index, vc[1], bar_width,
                 alpha=opacity,
                 color='mediumspringgreen',
                 label='Mexico')
 
rects2 = plt.bar(index + bar_width, vc[0], bar_width,
                 alpha=opacity,
                 color='hotpink',
                 label='Colombia')

rects3 = plt.bar(index + bar_width*2, vc[3], bar_width,
                 alpha=opacity,
                 color='dodgerblue',
                 label='USA')
 
rects4 = plt.bar(index + bar_width*3, vc[2], bar_width,
                 alpha=opacity,
                 color='sandybrown',
                 label='India')
 
plt.xlabel('years', fontsize = fsize)
plt.ylabel('Gross enrollment ratio, tertiary, both sexes (%)', fontsize = fsize - 2)
plt.title('Educational Levels of Countries (2004 - 2012)', fontsize = fsize)
plt.xticks(index + bar_width*3/2, namelist, fontsize = fsize)
plt.yticks(fontsize = fsize)
plt.legend()
 
plt.tight_layout()
plt.show()
fig.savefig("ccbareduc.png")

# %%
data
# Out:
#    EDULIT_IND                                        Indicator LOCATION  \
# 0     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 1     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 2     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 3     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 4     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 5     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 6     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 7     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 8     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 9     GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 10    GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# 11    GER_5T8  Gross enrolment ratio, tertiary, both sexes (%)      COL
# ...

# %%
print(vc)
# Out:
# [[26.61448, 29.185129999999997, 31.331640000000004, 32.63217, 35.24565, 37.07863, 39.4091, 43.502959999999995, 46.21575], [22.56222, 23.12034, 23.60797, 24.142979999999998, 24.7486, 25.19286, 26.166439999999998, 27.03765, 28.307440000000003], [10.98428, 10.73016, 11.540560000000001, 13.188770000000002, 15.1171, 16.10299, 17.91149, 22.86137, 24.36533], [81.46356, 82.08444, 82.053, 83.03106, 85.00681999999999, 88.58174, 94.22801, 96.3224, 94.84228]]
