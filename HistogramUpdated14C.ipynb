# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('14countries.csv',index_col=['Country Code'])

# %%
data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('14countries.csv',index_col=['Country Code'])

# %%
data
# Out:
#                                                    Series Name  \
# Country Code
# ESP                 Intentional homicides (per 100,000 people)
# JPN                 Intentional homicides (per 100,000 people)
# SWE                 Intentional homicides (per 100,000 people)
# PRT                 Intentional homicides (per 100,000 people)
# ITA                 Intentional homicides (per 100,000 people)
# AUS                 Intentional homicides (per 100,000 people)
# FIN                 Intentional homicides (per 100,000 people)
# ROU                 Intentional homicides (per 100,000 people)
# HUN                 Intentional homicides (per 100,000 people)
# GBR                 Intentional homicides (per 100,000 people)
# FRA                 Intentional homicides (per 100,000 people)
# CHN                 Intentional homicides (per 100,000 people)
# MAR                 Intentional homicides (per 100,000 people)
# AUT                 Intentional homicides (per 100,000 people)
# NaN                                                        NaN
# NaN                                                        NaN
# NaN                                                        NaN
# NaN           Data from database: World Development Indicators
# NaN                                   Last Updated: 03/23/2017
#
#                  Series Code    Country Name 1994 [YR1994]      1995 [YR1995]  \
# Country Code
# ESP           VC.IHR.PSRC.P5           Spain            ..    1.0424372395714
# JPN           VC.IHR.PSRC.P5           Japan            ..  0.543833004420133
# SWE           VC.IHR.PSRC.P5          Sweden            ..  0.940302249395573
# PRT           VC.IHR.PSRC.P5        Portugal            ..                 ..
# ITA           VC.IHR.PSRC.P5           Italy            ..   1.77643467769709
# AUS           VC.IHR.PSRC.P5       Australia            ..   1.79927428534592
# FIN           VC.IHR.PSRC.P5         Finland            ..    2.8583723488107
# ROU           VC.IHR.PSRC.P5         Romania            ..   3.34201109882768
# HUN           VC.IHR.PSRC.P5         Hungary            ..   2.86505133910661
# GBR           VC.IHR.PSRC.P5  United Kingdom            ..   1.46863785301919
# FRA           VC.IHR.PSRC.P5          France            ..   2.30964046176144
# CHN           VC.IHR.PSRC.P5           China            ..                 ..
# MAR           VC.IHR.PSRC.P5         Morocco            ..                 ..
# AUT           VC.IHR.PSRC.P5         Austria            ..   1.03331508650107
# NaN                      NaN             NaN           NaN                NaN
# NaN                      NaN             NaN           NaN                NaN
# NaN                      NaN             NaN           NaN                NaN
# NaN                      NaN             NaN           NaN                NaN
# NaN                      NaN             NaN           NaN                NaN
#
#                   1996 [YR1996]      1997 [YR1997]      1998 [YR1998]  \
# Country Code
# ESP            1.00456716212155   1.16893652427252   1.31373525561828
# JPN           0.493530480386386  0.541203531611255  0.571311769404654
# SWE             1.0963646920385   1.02779171383026   1.05053289128114
# PRT            1.04237920496755   1.11641232867845   1.21923456648993
# ITA            1.67374034178937   1.53458619786494   1.54085584551281
# AUS            1.70309051429349   1.73277921105429   1.52122687961993
# FIN            2.98526275287663   2.70467112269342    2.1937385653804
# ROU            3.19930731894723   3.08473623546624      2.50753657774
# HUN            2.62749838980887   2.80818575458866   2.81539704599579
# GBR            1.32075471698113     1.433281613654   1.45011600928074
# FRA            2.01696350708443   1.65263956656979   1.64284349848874
# CHN                          ..                 ..                 ..
# MAR                          ..                 ..                 ..
# AUT            1.24364609902136  0.827944065604281   0.96538202736996
# NaN                         NaN                NaN                NaN
# NaN                         NaN                NaN                NaN
# NaN                         NaN                NaN                NaN
# NaN                         NaN                NaN                NaN
# NaN                         NaN                NaN                NaN
#
#                   1999 [YR1999] 2000 [YR2000]      ...       2005 [YR2005]  \
# Country Code                                       ...
# ESP            1.21655384339648           1.4      ...                 1.2
# JPN           0.536916519813227            ..      ...                 0.5
# SWE            1.11832979816858           1.1      ...                 0.9
# PRT            1.05890339575747           1.1      ...                 1.3
# ITA            1.41541754017417           1.3      ...                 1.0
# AUS            1.81022756407651           1.9      ...                 1.3
# FIN            2.77024677474504           2.9      ...                 2.3
# ROU            2.54008829275101           2.5      ...                 2.1
# HUN            2.47132530045162             2      ...                 1.6
# GBR            1.47497737469432           1.7      ...                 1.5
# FRA            1.62208425674125           1.8      ...                 1.6
# CHN                          ..            ..      ...                 1.6
# MAR            1.89843953192356           1.6      ...                 1.5
# AUT           0.751437688156866             1      ...                 0.7
# NaN                         NaN           NaN      ...                 NaN
# NaN                         NaN           NaN      ...                 NaN
# NaN                         NaN           NaN      ...                 NaN
# NaN                         NaN           NaN      ...                 NaN
# NaN                         NaN           NaN      ...                 NaN
#
#              2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  2009 [YR2009]  \
# Country Code
# ESP                    1.1            1.1            0.9           0.90
# JPN                    0.5            0.5            0.5           0.40
# SWE                    0.1            1.2            0.8           0.90
# PRT                    1.5            1.8            1.2           1.20
# ITA                    1.1            1.1            1.0           0.98
# AUS                    1.4            1.2            1.2           1.20
# FIN                    2.3            2.4            2.5           2.20
# ROU                    2.1            2.0            2.3           1.90
# HUN                    1.7            1.5            1.8           1.40
# GBR                    1.4            1.4            1.2           1.10
# FRA                    1.4            1.6            1.6           1.30
# CHN                    1.4            1.2            1.1           1.10
# MAR                    1.6            1.7            1.4           1.40
# AUT                    0.7            0.5            0.7           0.60
# NaN                    NaN            NaN            NaN            NaN
# NaN                    NaN            NaN            NaN            NaN
# NaN                    NaN            NaN            NaN            NaN
# NaN                    NaN            NaN            NaN            NaN
# NaN                    NaN            NaN            NaN            NaN
#
#               2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# Country Code
# ESP                     0.8            0.8            0.8            0.7
# JPN                     0.4            0.3            0.3            0.3
# SWE                     0.1            0.9            0.7            0.9
# PRT                     1.2            1.1            1.2            1.4
# ITA                     0.9            0.9            0.9            0.8
# AUS                     1.1            1.1            1.1            1.1
# FIN                     2.2            2.0            1.6            1.6
# ROU                     2.0            1.7            1.9            1.7
# HUN                     1.4            1.5            1.2            1.6
# GBR                     1.2            1.0            1.0            0.9
# FRA                     1.3            1.4            1.2            1.2
# CHN                     1.0            0.9            0.8             ..
# MAR                     1.4            1.4            1.2            1.3
# AUT                     0.7            0.9            1.0            0.7
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
#
#               2014 [YR2014]
# Country Code
# ESP                     0.7
# JPN                     0.3
# SWE                     0.9
# PRT                     0.9
# ITA                     0.8
# AUS                       1
# FIN                     1.6
# ROU                     1.5
# HUN                     1.5
# GBR                      ..
# FRA                     1.2
# CHN                      ..
# MAR                       1
# AUT                     0.5
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
# NaN                     NaN
#
# [19 rows x 24 columns]

# %%
data = data.head(14)

# %%
data
# Out:
#                                              Series Name     Series Code  \
# Country Code
# ESP           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# JPN           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# SWE           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# PRT           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# ITA           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# AUS           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# FIN           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# ROU           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# HUN           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# GBR           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# FRA           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# CHN           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# MAR           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# AUT           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
#
#                 Country Name 1994 [YR1994]      1995 [YR1995]  \
# Country Code
# ESP                    Spain            ..    1.0424372395714
# JPN                    Japan            ..  0.543833004420133
# SWE                   Sweden            ..  0.940302249395573
# PRT                 Portugal            ..                 ..
# ITA                    Italy            ..   1.77643467769709
# AUS                Australia            ..   1.79927428534592
# FIN                  Finland            ..    2.8583723488107
# ROU                  Romania            ..   3.34201109882768
# HUN                  Hungary            ..   2.86505133910661
# GBR           United Kingdom            ..   1.46863785301919
# FRA                   France            ..   2.30964046176144
# CHN                    China            ..                 ..
# MAR                  Morocco            ..                 ..
# AUT                  Austria            ..   1.03331508650107
#
#                   1996 [YR1996]      1997 [YR1997]      1998 [YR1998]  \
# Country Code
# ESP            1.00456716212155   1.16893652427252   1.31373525561828
# JPN           0.493530480386386  0.541203531611255  0.571311769404654
# SWE             1.0963646920385   1.02779171383026   1.05053289128114
# PRT            1.04237920496755   1.11641232867845   1.21923456648993
# ITA            1.67374034178937   1.53458619786494   1.54085584551281
# AUS            1.70309051429349   1.73277921105429   1.52122687961993
# FIN            2.98526275287663   2.70467112269342    2.1937385653804
# ROU            3.19930731894723   3.08473623546624      2.50753657774
# HUN            2.62749838980887   2.80818575458866   2.81539704599579
# GBR            1.32075471698113     1.433281613654   1.45011600928074
# FRA            2.01696350708443   1.65263956656979   1.64284349848874
# CHN                          ..                 ..                 ..
# MAR                          ..                 ..                 ..
# AUT            1.24364609902136  0.827944065604281   0.96538202736996
#
#                   1999 [YR1999] 2000 [YR2000]      ...       2005 [YR2005]  \
# Country Code                                       ...
# ESP            1.21655384339648           1.4      ...                 1.2
# JPN           0.536916519813227            ..      ...                 0.5
# SWE            1.11832979816858           1.1      ...                 0.9
# PRT            1.05890339575747           1.1      ...                 1.3
# ITA            1.41541754017417           1.3      ...                 1.0
# AUS            1.81022756407651           1.9      ...                 1.3
# FIN            2.77024677474504           2.9      ...                 2.3
# ROU            2.54008829275101           2.5      ...                 2.1
# HUN            2.47132530045162             2      ...                 1.6
# GBR            1.47497737469432           1.7      ...                 1.5
# FRA            1.62208425674125           1.8      ...                 1.6
# CHN                          ..            ..      ...                 1.6
# MAR            1.89843953192356           1.6      ...                 1.5
# AUT           0.751437688156866             1      ...                 0.7
#
#              2006 [YR2006]  2007 [YR2007]  2008 [YR2008]  2009 [YR2009]  \
# Country Code
# ESP                    1.1            1.1            0.9           0.90
# JPN                    0.5            0.5            0.5           0.40
# SWE                    0.1            1.2            0.8           0.90
# PRT                    1.5            1.8            1.2           1.20
# ITA                    1.1            1.1            1.0           0.98
# AUS                    1.4            1.2            1.2           1.20
# FIN                    2.3            2.4            2.5           2.20
# ROU                    2.1            2.0            2.3           1.90
# HUN                    1.7            1.5            1.8           1.40
# GBR                    1.4            1.4            1.2           1.10
# FRA                    1.4            1.6            1.6           1.30
# CHN                    1.4            1.2            1.1           1.10
# MAR                    1.6            1.7            1.4           1.40
# AUT                    0.7            0.5            0.7           0.60
#
#               2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# Country Code
# ESP                     0.8            0.8            0.8            0.7
# JPN                     0.4            0.3            0.3            0.3
# SWE                     0.1            0.9            0.7            0.9
# PRT                     1.2            1.1            1.2            1.4
# ITA                     0.9            0.9            0.9            0.8
# AUS                     1.1            1.1            1.1            1.1
# FIN                     2.2            2.0            1.6            1.6
# ROU                     2.0            1.7            1.9            1.7
# HUN                     1.4            1.5            1.2            1.6
# GBR                     1.2            1.0            1.0            0.9
# FRA                     1.3            1.4            1.2            1.2
# CHN                     1.0            0.9            0.8             ..
# MAR                     1.4            1.4            1.2            1.3
# AUT                     0.7            0.9            1.0            0.7
#
#               2014 [YR2014]
# Country Code
# ESP                     0.7
# JPN                     0.3
# SWE                     0.9
# PRT                     0.9
# ITA                     0.8
# AUS                       1
# FIN                     1.6
# ROU                     1.5
# HUN                     1.5
# GBR                      ..
# FRA                     1.2
# CHN                      ..
# MAR                       1
# AUT                     0.5
#
# [14 rows x 24 columns]

# %%
d = data.dropna()
plt.hist(d["2004 [YR2004]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2004')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2007 [YR2007]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2007')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2010 [YR2010]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2010')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2012 [YR2012]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2012')
plt.show()
