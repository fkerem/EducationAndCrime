# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('4countries.csv',index_col=['Country Code'])

# %%
data
# Out:
#                                                    Series Name  \
# Country Code
# MEX                 Intentional homicides (per 100,000 people)
# IND                 Intentional homicides (per 100,000 people)
# USA                 Intentional homicides (per 100,000 people)
# COL                 Intentional homicides (per 100,000 people)
# NaN                                                        NaN
# NaN                                                        NaN
# NaN                                                        NaN
# NaN           Data from database: World Development Indicators
# NaN                                   Last Updated: 03/23/2017
#
#                  Series Code   Country Name 1994 [YR1994]  1995 [YR1995]  \
# Country Code
# MEX           VC.IHR.PSRC.P5         Mexico            ..      16.919405
# IND           VC.IHR.PSRC.P5          India            ..       4.366263
# USA           VC.IHR.PSRC.P5  United States            ..       8.112683
# COL           VC.IHR.PSRC.P5       Colombia            ..      69.672634
# NaN                      NaN            NaN           NaN            NaN
# NaN                      NaN            NaN           NaN            NaN
# NaN                      NaN            NaN           NaN            NaN
# NaN                      NaN            NaN           NaN            NaN
# NaN                      NaN            NaN           NaN            NaN
#
#               1996 [YR1996]  1997 [YR1997]  1998 [YR1998]  1999 [YR1999]  \
# Country Code
# MEX               15.454135      14.199297      14.078070      12.433805
# IND                4.395080       4.352471       4.473274       4.233402
# USA                7.292303       6.678322       6.150310       5.557464
# COL               71.786900      67.184550      60.084655      62.292449
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
#
#               2000 [YR2000]      ...        2005 [YR2005]  2006 [YR2006]  \
# Country Code                     ...
# MEX                    10.4      ...                    9            9.4
# IND                     4.5      ...                  3.6            3.6
# USA                     5.5      ...                   ..            5.8
# COL                    65.7      ...                 39.5           36.8
# NaN                     NaN      ...                  NaN            NaN
# NaN                     NaN      ...                  NaN            NaN
# NaN                     NaN      ...                  NaN            NaN
# NaN                     NaN      ...                  NaN            NaN
# NaN                     NaN      ...                  NaN            NaN
#
#               2007 [YR2007]  2008 [YR2008] 2009 [YR2009]  2010 [YR2010]  \
# Country Code
# MEX                     7.8           12.2          17.0           21.7
# IND                     3.5            3.5           3.4            3.4
# USA                     5.7            5.4           5.0            4.8
# COL                    34.8           33.2          34.0           32.7
# NaN                     NaN            NaN           NaN            NaN
# NaN                     NaN            NaN           NaN            NaN
# NaN                     NaN            NaN           NaN            NaN
# NaN                     NaN            NaN           NaN            NaN
# NaN                     NaN            NaN           NaN            NaN
#
#               2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  2014 [YR2014]
# Country Code
# MEX                    22.6           21.3           18.6           15.7
# IND                     3.5            3.4            3.3            3.2
# USA                     4.7            4.7            3.9             ..
# COL                    34.1           31.3           32.6           27.9
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
# NaN                     NaN            NaN            NaN            NaN
#
# [9 rows x 24 columns]

# %%
data.head(4)
# Out:
#                                              Series Name     Series Code  \
# Country Code
# MEX           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# IND           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# USA           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# COL           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
#
#                Country Name 1994 [YR1994]  1995 [YR1995]  1996 [YR1996]  \
# Country Code
# MEX                  Mexico            ..      16.919405      15.454135
# IND                   India            ..       4.366263       4.395080
# USA           United States            ..       8.112683       7.292303
# COL                Colombia            ..      69.672634      71.786900
#
#               1997 [YR1997]  1998 [YR1998]  1999 [YR1999]  2000 [YR2000]  \
# Country Code
# MEX               14.199297      14.078070      12.433805           10.4
# IND                4.352471       4.473274       4.233402            4.5
# USA                6.678322       6.150310       5.557464            5.5
# COL               67.184550      60.084655      62.292449           65.7
#
#                   ...        2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  \
# Country Code      ...
# MEX               ...                    9            9.4            7.8
# IND               ...                  3.6            3.6            3.5
# USA               ...                   ..            5.8            5.7
# COL               ...                 39.5           36.8           34.8
#
#               2008 [YR2008] 2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  \
# Country Code
# MEX                    12.2          17.0           21.7           22.6
# IND                     3.5           3.4            3.4            3.5
# USA                     5.4           5.0            4.8            4.7
# COL                    33.2          34.0           32.7           34.1
#
#               2012 [YR2012]  2013 [YR2013]  2014 [YR2014]
# Country Code
# MEX                    21.3           18.6           15.7
# IND                     3.4            3.3            3.2
# USA                     4.7            3.9             ..
# COL                    31.3           32.6           27.9
#
# [4 rows x 24 columns]

# %%
data = data.head(4)

# %%
data
# Out:
#                                              Series Name     Series Code  \
# Country Code
# MEX           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# IND           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# USA           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
# COL           Intentional homicides (per 100,000 people)  VC.IHR.PSRC.P5
#
#                Country Name 1994 [YR1994]  1995 [YR1995]  1996 [YR1996]  \
# Country Code
# MEX                  Mexico            ..      16.919405      15.454135
# IND                   India            ..       4.366263       4.395080
# USA           United States            ..       8.112683       7.292303
# COL                Colombia            ..      69.672634      71.786900
#
#               1997 [YR1997]  1998 [YR1998]  1999 [YR1999]  2000 [YR2000]  \
# Country Code
# MEX               14.199297      14.078070      12.433805           10.4
# IND                4.352471       4.473274       4.233402            4.5
# USA                6.678322       6.150310       5.557464            5.5
# COL               67.184550      60.084655      62.292449           65.7
#
#                   ...        2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  \
# Country Code      ...
# MEX               ...                    9            9.4            7.8
# IND               ...                  3.6            3.6            3.5
# USA               ...                   ..            5.8            5.7
# COL               ...                 39.5           36.8           34.8
#
#               2008 [YR2008] 2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  \
# Country Code
# MEX                    12.2          17.0           21.7           22.6
# IND                     3.5           3.4            3.4            3.5
# USA                     5.4           5.0            4.8            4.7
# COL                    33.2          34.0           32.7           34.1
#
#               2012 [YR2012]  2013 [YR2013]  2014 [YR2014]
# Country Code
# MEX                    21.3           18.6           15.7
# IND                     3.4            3.3            3.2
# USA                     4.7            3.9             ..
# COL                    31.3           32.6           27.9
#
# [4 rows x 24 columns]

# %%
d = data.dropna()
plt.hist(d["2004 [YR2004]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2004')
plt.show()
plt.savefig("2004az.png")

# %%
d = data.dropna()
plt.hist(d["2004 [YR2004]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2004')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2007 [YR2007]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2007')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2010 [YR2010]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2010')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2012 [YR2012]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2012')
plt.show()
