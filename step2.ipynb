# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('crime14.csv',index_col=['Country Code'])

# %%
d = data.dropna()
plt.hist(d["2010 [YR2010]"])
# Out:
# (array([ 14.,   2.,   0.,   0.,   0.,   0.,   1.,   0.,   0.,   1.]),
#  array([  0.1 ,   3.36,   6.62,   9.88,  13.14,  16.4 ,  19.66,  22.92,
#          26.18,  29.44,  32.7 ]),
#  <a list of 10 Patch objects>)

# %%
plt.show()

# %%
d = data.dropna()
plt.hist(d["2010 [YR2010]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2010')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2012 [YR2012]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2012')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2004 [YR2004]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2004')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2004 [YR2004]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2004')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2007 [YR2007]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2007')
plt.show()

# %%
d = data.dropna()
plt.hist(d["2010 [YR2010]"])
plt.xlabel('Intentional homicides (per 100,000 people)')
plt.ylabel('Number of Countries')
plt.title('2010')
plt.show()
